# %% [markdown]
# <a href="https://colab.research.google.com/github/TxcBoT/Algorithms/blob/main/Lab_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Greedy Knapsack Problem (Fractional)
# In this lab, we explore the Fractional Knapsack Problem, a fundamental optimization problem that demonstrates the Greedy Algorithmic Paradigm.
# We will implement it using greedy selection (based on value-to-weight ratio) and analyze its time and space complexity.

# %% [markdown]
# - Created by Dr. Ajay

# %% [markdown]
# # Problem Definition
# Given a set of
# n
# n items, each with:
# Value vi
# Weight wi
# A knapsack with maximum capacity **W**
#
# Goal: maximize total value that can be put in the knapsack.
# Constraint: You may take fractions of items.
#
# Greedy Strategy:
#
# *  Sort items by decreasing ratio vi/wi
# *  Select items fully until knapsack is full.
# *  Take fraction of the next item if capacity remains.

# %%
def fractional_knapsack(value, weight, capacity):
    items = []
    for i in range(len(value)):
        items.append({'value': value[i], 'weight': weight[i], 'ratio': value[i] / weight[i]})


    items.sort(key=lambda x: x['ratio'], reverse=True)

    total_value = 0
    knapsack_capacity = capacity
    result = []

    for item in items:
        if knapsack_capacity == 0:
            break

        if item['weight'] <= knapsack_capacity:

            total_value += item['value']
            knapsack_capacity -= item['weight']
            result.append(f"Took full item (Value: {item['value']}, Weight: {item['weight']}, Ratio: {item['ratio']:.2f})")
        else:

            fraction = knapsack_capacity / item['weight']
            total_value += item['value'] * fraction
            knapsack_capacity = 0
            result.append(f"Took fraction of item (Value: {item['value'] * fraction:.2f}, Weight: {item['weight'] * fraction:.2f}, Ratio: {item['ratio']:.2f})")
            break

    print("Items selected and their quantities:")
    for line in result:
        print(line)
    return total_value


values = [60, 100, 1020]
weights = [10, 20, 30]
capacity = 50

max_value = fractional_knapsack(values, weights, capacity)
print(f"\nMaximum value in knapsack: {max_value:.2f}")
# Out:
# Items selected and their quantities:
# Took full item (Value: 1020, Weight: 30, Ratio: 34.00)
# Took full item (Value: 60, Weight: 10, Ratio: 6.00)
# Took fraction of item (Value: 50.00, Weight: 10.00, Ratio: 5.00)
#
# Maximum value in knapsack: 1130.00

# %% [markdown]
# In this lab, we implement Huffman Coding, a greedy algorithm used for lossless data compression.
# It assigns variable-length binary codes to input symbols based on their frequencies, ensuring that more frequent symbols receive shorter codes and less frequent symbols receive longer codes.
#
# This algorithm constructs a binary tree (Huffman Tree) where each leaf node represents a character, and the path from the root to a leaf gives the character’s binary code.
#
# Use:
# Huffman Tree Construction using a Min-Priority Queue (Min-Heap).
# Code generation for each character.
# Encoding and decoding using the generated Huffman codes.
# Complexity analysis and comparison with fixed-length encoding.
#
# # Pseudocode:
# 1. Create a leaf node for each character and insert all nodes into a
# 2. min-heap by frequency.
#    *  While the heap has more than one node:
#    * Extract two nodes with the lowest frequencies.
#    * Create a new internal node with frequency = sum of the two.
#    *  Set the two extracted nodes as left and right children.
#    *  Insert the new node back into the min-heap.
# 3. The remaining node is the root of the Huffman Tree.
#
# 4. Traverse the tree:
#    * Assign 0 for left edge and 1 for right edge.
#    * The resulting paths from root to leaves give Huffman codes.

# %%
import heapq
from collections import Counter

class Node:
    def __init__(self, char, freq):
        self.char = char
        self.freq = freq
        self.left = None
        self.right = None

    def __lt__(self, other):
        return self.freq < other.freq

def generate_codes(root, code, huffman_code):
    if root is None:
        return

    if root.char is not None:
        huffman_code[root.char] = code

    generate_codes(root.left, code + "0", huffman_code)
    generate_codes(root.right, code + "1", huffman_code)

def decode(root, encoded):
    result = ""
    current = root

    for bit in encoded:
        if bit == '0':
            current = current.left
        else:
            current = current.right

        if current.left is None and current.right is None:
            result += current.char
            current = root

    return result

def huffman_coding(text):

    freq = Counter(text)

    heap = []
    for char, f in freq.items():
        heapq.heappush(heap, Node(char, f))

    while len(heap) > 1:
        left = heapq.heappop(heap)
        right = heapq.heappop(heap)

        new_node = Node(None, left.freq + right.freq)
        new_node.left = left
        new_node.right = right

        heapq.heappush(heap, new_node)

    root = heap[0]

    huffman_code = {}
    generate_codes(root, "", huffman_code)

    encoded = ""
    for ch in text:
        encoded += huffman_code[ch]

    decoded = decode(root, encoded)

    print("Huffman Codes:")
    for char, code in huffman_code.items():
        print(char, ":", code)

    print("\nEncoded String:")
    print(encoded)

    print("\nDecoded String:")
    print(decoded)


text = "huffman"
huffman_coding(text)
# Out:
# Huffman Codes:
# a : 00
# f : 01
# h : 100
# n : 101
# u : 110
# m : 111
#
# Encoded String:
# 100110010111100101
#
# Decoded String:
# huffman
